# %% [markdown]
# # Golf Stats and Info Tracker

# %% [markdown]
# ### Description
#
# ##### Welcome to my golf stats tracker!  Thanks for taking the time to check this out and give it a try!
#
# To begin, click in the cell below then press 'ctrl+enter' or click the 'Run' button on the toolbar.
#
# When prompted for input, type in your response and hit 'enter' to receive the data
#
# Remember; capitalization and spelling matter - inputs must match your values in the excel csv file
#
# examples of inputs:\
# -Year: 2021, 2022, etc. \
# -Single Round: 7/14/2021, 9/2/2021, etc. \
# -Months: March, July, September
#
# To reset and run the tracker for a different year, single round, or group of months - click 'Kernel' in the tool bar, and select 'Restart & Run All', then confirm this on the pop-up prompt.
#
# If you make an incorrect/unrecognized input - an error message should appear.  Repeat the 'Restart & Run All' process above to enter in a new input.
#
# Comprehensive documentation and use can be found in the word file "read_me"
#
# If you have any other questions, suggestions, or things aren't working right - feel free to DM me on the refuge @TBuhr33! (screen shots of the error or issue would be appreciated)
#
# Thanks for indulging me, hope you find this useful in some way, and cheers to the 2022 Season! Craic on!

# %%
#click here to select this cell- then press 'ctrl+enter' or click 'Run' in the toolbar to get started

from ipynb.fs.full.Functions_ref import *
# Out:
# Enter Desired Year: 2021
#
# ------------------------------------------------
# Courses Played in 2021
# ------------------------------------------------
#               Courses
# 0              Keller
# 1             Pioneer
# 2  St. Croix National
# Number of Rounds Played: 3
#
# ------------------------------------------------
# All Stats for 2021 Season
# ------------------------------------------------
# Average Score Per 18: 76.4
# Average 4.4 Strokes Over Par
# Average Score to Par: 0.24
#
# FIR and GIR Stats
# ------------------------------------------------
# FIR Percentage: 60.0%
# GIR Percentage: 53.33%
# Total Number of Missed FIR: 14
# Missed FIR Percentage: 40.0%
# Total Number of FIR Missed Right: 9
# Missed FIR Right Percentage: 64.29%
# Total Number of FIR Missed Left: 5
# Missed FIR Left Percentage: 35.71%
# Total Number of Missed GIR: 21
# Total Missed GIR Percentage: 46.67%
# Total GIR Missed Right: 4
# Missed GIR Right Percentage: 19.0%
# ...
